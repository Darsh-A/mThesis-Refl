# %%
# run this command in the cell : uv run python -m src.salvadori.fig4
# Out:
# /home/ardo/mlem/Vaults/Thesis/Repl/.venv/bin/python: No module named uv
# Note: you may need to restart the kernel to use updated packages.
